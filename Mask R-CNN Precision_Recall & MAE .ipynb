# %%
def Precision_Recall(realImg, predImg, height, width, channel):
    TP = 0.0
    FP = 0.0
    FN = 0.0
    TN = 0.0
    for k in range(channel):
        for i in range(height):
            for j in range(width):
                if realImg[i, j, k] == True:
                    if predImg[i, j, k] == True:
                        TP += 1
                    elif predImg[i, j, k] == False:
                        FN += 1
                elif realImg[i, j, k] == False:
                    if predImg[i, j, k] == True:
                        FP += 1
                    elif predImg[i, j, k] == False:
                        TN += 1
    print(TP, FP, FN, TN)
    print("Precision: %.4f" % (TP / (TP + FP)))
    print("Recall: %.4f" % (TP / (TP + FN)))
    print("F1: %.4f" % ((2 * TP) / (2*TP + FP + FN)))
    print(" ")
    return (TP / (TP + FP)), (TP / (TP + FN)), ((2 * TP) / (2*TP + FP + FN))

# %%
def MAE(realImg, predImg, height, width, channel):
    mae = 0.0
    for k in range(channel):
        for i in range(height):
            for j in range(width):
                mae += abs(float(predImg[i, j, k]) - float(realImg[i, j, k]))
    print("MAE : %.4f" % (mae / (height * width)))
    return (mae / (height * width))

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

predimg1 = cv2.imread('/home/user/Mask_RCNN/images/1.jpg')
predimg1 = cv2.resize(predimg1,(705, 872))
realimg1 = cv2.imread('/home/user/Mask_RCNN/gt/gt1.PNG')
predimg1 = predimg1.astype(np.bool)
realimg1 = realimg1.astype(np.bool)


predimg2 = cv2.imread('/home/user/Mask_RCNN/images/2.jpg')
predimg2 = cv2.resize(predimg2,(672, 904))
realimg2 = cv2.imread('/home/user/Mask_RCNN/gt/gt2.PNG')
predimg2 = predimg2.astype(np.bool)
realimg2 = realimg2.astype(np.bool)


predimg3 = cv2.imread('/home/user/Mask_RCNN/images/3.jpg')
predimg3 = cv2.resize(predimg3,(800, 800))
realimg3 = cv2.imread('/home/user/Mask_RCNN/gt/gt3.PNG')
predimg3 = predimg3.astype(np.bool)
realimg3 = realimg3.astype(np.bool)

predimg4 = cv2.imread('/home/user/Mask_RCNN/images/4.jpg')
predimg4 = cv2.resize(predimg4,(701, 876))
realimg4 = cv2.imread('/home/user/Mask_RCNN/gt/gt4.PNG')
predimg4 = predimg4.astype(np.bool)
realimg4 = realimg4.astype(np.bool)

predimg5 = cv2.imread('/home/user/Mask_RCNN/images/5.jpg')
predimg5 = cv2.resize(predimg5,(653, 926))
realimg5 = cv2.imread('/home/user/Mask_RCNN/gt/gt5.PNG')
predimg5 = predimg5.astype(np.bool)
realimg5 = realimg5.astype(np.bool)

predimg6 = cv2.imread('/home/user/Mask_RCNN/images/6.jpg')
predimg6 = cv2.resize(predimg6,(634, 951))
realimg6 = cv2.imread('/home/user/Mask_RCNN/gt/gt6.PNG')
predimg6 = predimg6.astype(np.bool)
realimg6 = realimg6.astype(np.bool)

predimg7 = cv2.imread('/home/user/Mask_RCNN/images/7.jpg')
predimg7 = cv2.resize(predimg7,(564, 1003))
realimg7 = cv2.imread('/home/user/Mask_RCNN/gt/gt7.PNG')
predimg7 = predimg7.astype(np.bool)
realimg7 = realimg7.astype(np.bool)

predimg8 = cv2.imread('/home/user/Mask_RCNN/images/8.jpg')
predimg8 = cv2.resize(predimg8,(634, 951))
realimg8 = cv2.imread('/home/user/Mask_RCNN/gt/gt8.PNG')
predimg8 = predimg8.astype(np.bool)
realimg8 = realimg8.astype(np.bool)

predimg9 = cv2.imread('/home/user/Mask_RCNN/images/9.jpg')
predimg9 = cv2.resize(predimg9,(634, 951))
realimg9 = cv2.imread('/home/user/Mask_RCNN/gt/gt9.PNG')
predimg9 = predimg9.astype(np.bool)
realimg9 = realimg9.astype(np.bool)

predimg10 = cv2.imread('/home/user/Mask_RCNN/images/10.jpg')
predimg10 = cv2.resize(predimg10,(634, 951))
realimg10 = cv2.imread('/home/user/Mask_RCNN/gt/gt10.PNG')
predimg10 = predimg10.astype(np.bool)
realimg10 = realimg10.astype(np.bool)

predimg11 = cv2.imread('/home/user/Mask_RCNN/images/11.jpg')
predimg11 = cv2.resize(predimg11,(634, 951))
realimg11 = cv2.imread('/home/user/Mask_RCNN/gt/gt11.PNG')
predimg11 = predimg11.astype(np.bool)
realimg11 = realimg11.astype(np.bool)

predimg12 = cv2.imread('/home/user/Mask_RCNN/images/12.jpg')
predimg12 = cv2.resize(predimg12,(668, 909))
realimg12 = cv2.imread('/home/user/Mask_RCNN/gt/gt12.PNG')
predimg12 = predimg12.astype(np.bool)
realimg12 = realimg12.astype(np.bool)

predimg13 = cv2.imread('/home/user/Mask_RCNN/images/13.jpg')
predimg13 = cv2.resize(predimg13,(634, 951))
realimg13 = cv2.imread('/home/user/Mask_RCNN/gt/gt13.PNG')
predimg13 = predimg13.astype(np.bool)
realimg13 = realimg13.astype(np.bool)

predimg14 = cv2.imread('/home/user/Mask_RCNN/images/14.jpg')
predimg14 = cv2.resize(predimg14,(634, 951))
realimg14 = cv2.imread('/home/user/Mask_RCNN/gt/gt14.PNG')
predimg14 = predimg14.astype(np.bool)
realimg14 = realimg14.astype(np.bool)

predimg15 = cv2.imread('/home/user/Mask_RCNN/images/15.jpg')
predimg15 = cv2.resize(predimg15,(634, 951))
realimg15 = cv2.imread('/home/user/Mask_RCNN/gt/gt15.PNG')
predimg15 = predimg15.astype(np.bool)
realimg15 = realimg15.astype(np.bool)

predimg16 = cv2.imread('/home/user/Mask_RCNN/images/16.jpg')
predimg16 = cv2.resize(predimg16,(1350, 901))
realimg16 = cv2.imread('/home/user/Mask_RCNN/gt/gt16.PNG')
predimg16 = predimg16.astype(np.bool)
realimg16 = realimg16.astype(np.bool)

predimg17 = cv2.imread('/home/user/Mask_RCNN/images/17.jpg')
predimg17 = cv2.resize(predimg17,(634, 951))
realimg17 = cv2.imread('/home/user/Mask_RCNN/gt/gt17.PNG')
predimg17 = predimg17.astype(np.bool)
realimg17 = realimg17.astype(np.bool)

predimg18 = cv2.imread('/home/user/Mask_RCNN/images/18.jpg')
predimg18 = cv2.resize(predimg18,(1350, 900))
realimg18 = cv2.imread('/home/user/Mask_RCNN/gt/gt18.PNG')
predimg18 = predimg18.astype(np.bool)
realimg18 = realimg18.astype(np.bool)

predimg19 = cv2.imread('/home/user/Mask_RCNN/images/19.jpg')
predimg19 = cv2.resize(predimg19,(634, 951))
realimg19 = cv2.imread('/home/user/Mask_RCNN/gt/gt19.PNG')
predimg19 = predimg19.astype(np.bool)
realimg19 = realimg19.astype(np.bool)

predimg20 = cv2.imread('/home/user/Mask_RCNN/images/20.jpg')
predimg20 = cv2.resize(predimg20,(634, 951))
realimg20 = cv2.imread('/home/user/Mask_RCNN/gt/gt20.PNG')
predimg20 = predimg20.astype(np.bool)
realimg20 = realimg20.astype(np.bool)

predimg21 = cv2.imread('/home/user/Mask_RCNN/images/21.jpg')
predimg21 = cv2.resize(predimg21,(634, 950))
realimg21 = cv2.imread('/home/user/Mask_RCNN/gt/gt21.PNG')
predimg21 = predimg21.astype(np.bool)
realimg21 = realimg21.astype(np.bool)

predimg22 = cv2.imread('/home/user/Mask_RCNN/images/22.jpg')
predimg22 = cv2.resize(predimg22,(634, 951))
realimg22 = cv2.imread('/home/user/Mask_RCNN/gt/gt22.PNG')
predimg22 = predimg22.astype(np.bool)
realimg22 = realimg22.astype(np.bool)

predimg23 = cv2.imread('/home/user/Mask_RCNN/images/23.jpg')
predimg23 = cv2.resize(predimg23,(634, 950))
realimg23 = cv2.imread('/home/user/Mask_RCNN/gt/gt23.PNG')
predimg23 = predimg23.astype(np.bool)
realimg23 = realimg23.astype(np.bool)

# %%
print("1")
Precision_Recall(realimg1, predimg1, 872, 705, 3)

print("2")
Precision_Recall(realimg2, predimg2, 904, 672, 3)

print("3")
Precision_Recall(realimg3, predimg3, 800, 800, 3)

print("4")
Precision_Recall(realimg4, predimg4, 876, 701, 3)

print("5")
Precision_Recall(realimg5, predimg5, 926, 653, 3)

print("6")
Precision_Recall(realimg6, predimg6, 951, 634, 3)

print("7")
Precision_Recall(realimg7, predimg7, 1003, 564, 3)

print("8")
Precision_Recall(realimg8, predimg8, 951, 634, 3)

print("9")
Precision_Recall(realimg9, predimg9, 951, 634, 3)

print("10")
Precision_Recall(realimg10, predimg10, 951, 634, 3)

print("11")  
Precision_Recall(realimg11, predimg11, 951, 634, 3)

print("12")
Precision_Recall(realimg12, predimg12, 909, 668, 3)

print("13")
Precision_Recall(realimg13, predimg13, 951, 634, 3)

print("14")
Precision_Recall(realimg14, predimg14, 951, 634, 3)

print("15")
Precision_Recall(realimg15, predimg15, 951, 634, 3)

print("16")
Precision_Recall(realimg16, predimg16, 901, 1350, 3)

print("17")
Precision_Recall(realimg17, predimg17, 951, 634, 3)

print("18")
Precision_Recall(realimg18, predimg18, 900, 1350, 3)

print("19")
Precision_Recall(realimg19, predimg19, 951, 634, 3)

print("20")
Precision_Recall(realimg20, predimg20, 951, 634, 3)

print("21")
Precision_Recall(realimg21, predimg21, 950, 634, 3)

print("22")
Precision_Recall(realimg22, predimg22, 951, 634, 3)

print("23")
Precision_Recall(realimg23, predimg23, 950, 634, 3)
# Out:
# 1
# 619101.0 63891.0 150063.0 1011225.0
# Precision: 0.9065
# Recall: 0.8049
# F1: 0.8527
#
# 2
# 212777.0 17104.0 9843.0 1582740.0
# Precision: 0.9256
# Recall: 0.9558
# F1: 0.9404
#
# 3
# 926158.0 29343.0 78990.0 885509.0
# Precision: 0.9693
# Recall: 0.9214
# F1: 0.9447
#
# 4
# 711466.0 40099.0 46659.0 1044004.0
# Precision: 0.9466
# Recall: 0.9385
# F1: 0.9425
#
# 5
# 846656.0 28728.0 72571.0 866079.0
# Precision: 0.9672
# Recall: 0.9211
# F1: 0.9436
#
# 6
# 779067.0 48770.0 78751.0 902214.0
# Precision: 0.9411
# Recall: 0.9082
# F1: 0.9243
#
# 7
# 665167.0 18173.0 55923.0 957813.0
# Precision: 0.9734
# Recall: 0.9224
# F1: 0.9472
#
# 8
# 838228.0 76177.0 113278.0 781119.0
# Precision: 0.9167
# Recall: 0.8809
# F1: 0.8985
#
# 9
# 306121.0 4998.0 112038.0 1385645.0
# Precision: 0.9839
# Recall: 0.7321
# F1: 0.8395
#
# 10
# 836631.0 5932.0 53816.0 912423.0
# Precision: 0.9930
# Recall: 0.9396
# F1: 0.9655
#
# 11
# 333424.0 24182.0 63518.0 1387678.0
# Precision: 0.9324
# ...

# %%
print("1")
MAE(realimg1, predimg1, 872, 705, 3)

print("2")
MAE(realimg2, predimg2, 904, 672, 3)

print("3")
MAE(realimg3, predimg3, 800, 800, 3)

print("4")
MAE(realimg4, predimg4, 876, 701, 3)

print("5")
MAE(realimg5, predimg5, 926, 653, 3)

print("6")
MAE(realimg6, predimg6, 951, 634, 3)

print("7")
MAE(realimg7, predimg7, 1003, 564, 3)

print("8")
MAE(realimg8, predimg8, 951, 634, 3)

print("9")
MAE(realimg9, predimg9, 951, 634, 3)

print("10")
MAE(realimg10, predimg10, 951, 634, 3)

print("11")  
MAE(realimg11, predimg11, 951, 634, 3)

print("12")
MAE(realimg12, predimg12, 909, 668, 3)

print("13")
MAE(realimg13, predimg13, 951, 634, 3)

print("14")
MAE(realimg14, predimg14, 951, 634, 3)

print("15")
MAE(realimg15, predimg15, 951, 634, 3)

print("16")
MAE(realimg16, predimg16, 901, 1350, 3)

print("17")
MAE(realimg17, predimg17, 951, 634, 3)

print("18")
MAE(realimg18, predimg18, 900, 1350, 3)

print("19")
MAE(realimg19, predimg19, 951, 634, 3)

print("20")
MAE(realimg20, predimg20, 951, 634, 3)

print("21")
MAE(realimg21, predimg21, 950, 634, 3)

print("22")
MAE(realimg22, predimg22, 951, 634, 3)

print("23")
MAE(realimg23, predimg23, 950, 634, 3)
# Out:
# 1
# MAE : 0.3480
# 2
# MAE : 0.0444
# 3
# MAE : 0.1693
# 4
# MAE : 0.1413
# 5
# MAE : 0.1675
# 6
# MAE : 0.2115
# 7
# MAE : 0.1310
# 8
# MAE : 0.3142
# 9
# MAE : 0.1941
# 10
# MAE : 0.0991
# 11
# MAE : 0.1455
# 12
# MAE : 0.1534
# 13
# MAE : 0.0747
# 14
# MAE : 0.0815
# 15
# MAE : 0.0469
# 16
# MAE : 0.0963
# 17
# MAE : 0.1726
# 18
# MAE : 0.0478
# 19
# MAE : 0.0465
# 20
# MAE : 0.0204
# 21
# MAE : 0.1019
# 22
# MAE : 0.1061
# 23
# MAE : 0.0554
# 0.055369417233936576
